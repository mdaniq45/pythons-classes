# %%
print("mohammad")
# Out:
# mohammad

# %%
  from matplotlib import pyplot as plt 
plt.plot([1,3,5,7],[2,4,6,8])
plt.show()

# %%
x=[5,3,2,6]
y=[4,5,3,2]
plt.plot('line graph')
plt.ylabal("yaxis")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 4
#       2 y=[4,5,3,2]
#       3 plt.plot('line graph')
# ----> 4 plt.ylabal("yaxis")
#       5 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'ylabal'

# %%
name=["mohammad","zama","ossama","laiq","amiq"]
marks=[99,90,98,90,88]
plt.figure(figsize=(19,4))
plt.subplot(131)
plt.bar(name,marks)
plt.subplot(132)
plt.scatter(name,marks)
plt.plot(133)
plt.plot(name,marks)
#plt.subtitle('categorical ploting')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 10
#       8 plt.plot(133)
#       9 plt.plot(name,marks)
# ---> 10 plt.subtitle('categorical ploting')
#      11 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'subtitle'
